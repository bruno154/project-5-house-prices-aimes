# %% [markdown]
# ## 0.0 Bussines Problem

# %% [markdown]
# # 0.1 Helper Functions and Transformers

# %% [markdown]
# <!-- # 0.2 Imports -->

# %%
import pandas as pd
import numpy as np
from MyToolBox import MyToolBox as mb
from MyToolBox import CustomTransformers as ct
#pip install ../dist/MyToolBox-0.0.1.tar.gz




# Options
pd.set_option('MAX_COLUMNS', None)
pd.set_option('MAX_ROWS', None)

# %% [markdown]
# # 1.0 Collect Data

# %%
# train data
train = pd.read_csv('../data/train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# test data
test = pd.read_csv('../data/test.csv')
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # 2.0 Data Description
#
# Takeways:

# %%
describer = mb.DataDescription(train)
desc = describer.my_describe()
desc
# Out:
#                missingPerc  uniques  %uniquePerc data_types           mean  \
# 1stFlrSF          0.000000      753    51.575342      int64    1162.626712
# 2ndFlrSF          0.000000      417    28.561644      int64     346.992466
# 3SsnPorch         0.000000       20     1.369863      int64       3.409589
# Alley             0.937671        2     0.136986     object            NaN
# BedroomAbvGr      0.000000        8     0.547945      int64       2.866438
# BldgType          0.000000        5     0.342466     object            NaN
# BsmtCond          0.025342        4     0.273973     object            NaN
# BsmtExposure      0.026027        4     0.273973     object            NaN
# BsmtFinSF1        0.000000      637    43.630137      int64     443.639726
# BsmtFinSF2        0.000000      144     9.863014      int64      46.549315
# BsmtFinType1      0.025342        6     0.410959     object            NaN
# ...

# %% [markdown]
# # 3.0 Splitting data

# %% [markdown]
# # 4.0 EDA

# %% [markdown]
# # 6.0 Pre-Processing/Feature Eng

# %% [markdown]
# # 7.0 Machine Learning Modelling
